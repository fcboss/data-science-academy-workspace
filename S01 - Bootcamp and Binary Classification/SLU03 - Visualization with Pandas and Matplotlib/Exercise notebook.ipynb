# %% [markdown]
# # SLU03-Visualization with Pandas & Matplotlib: Exercise notebook

# %% [markdown]
# In this notebook you will practice the following:
#
# - Scatterplots
# - Line charts
# - Bar charts
# - Histograms
# - Box plots
# - Scaling plots

# %% [markdown]
# To learn about data visualization, we are going to use a modified version of [The Movies Dataset](https://www.kaggle.com/rounakbanik/the-movies-dataset) which has information about movies
#
# The dataset is located at `data/movies.csv`, and has the following fields
#
# ```
#     budget: Movie budget (in $).
#     genre: Genre the movie belongs to.
#     original_language: Language the movie was originally filmed in.
#     production_company: Name of the production company.
#     production_country: Country where the movie was produced.
#     release_year: Year the movie was released.
#     revenue: Movie ticket sales (in $).
#     runtime: Movie duration (in minutes).
#     title: Movie title.
#     vote_average: Average rating in MovieLens.
#     vote_count: Number of votes in MovieLens.
#     release_year: Year the movie was released
# ```

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("data/movies.csv")

# %%
movies.shape
# Out:
# (756, 11)

# %%
movies.head()
# Out:
#        budget   genre original_language     production_company  \
# 0   3500000.0  Comedy                en        New Line Cinema
# 1  12000000.0  Comedy                en     Universal Pictures
# 2  31000000.0  Comedy                en         United Artists
# 3  52000000.0   Drama                en  Imagine Entertainment
# 4   2000000.0  Comedy                en          Miramax Films
#
#          production_country      revenue  runtime             title  \
# 0  United States of America   28215918.0     91.0            Friday
# 1  United States of America   41205099.0     92.0     Happy Gilmore
# 2  United States of America  185260553.0    117.0      The Birdcage
# 3  United States of America  355237933.0    140.0         Apollo 13
# 4  United States of America    1275000.0     83.0  Blue in the Face
#
#    vote_average  vote_count  release_year
# 0           7.0       513.0        1995.0
# 1           6.5       767.0        1996.0
# 2           6.7       303.0        1996.0
# 3           7.3      1637.0        1995.0
# 4           6.8        28.0        1995.0

# %% [markdown]
# Import matplotlib, pyplot and the matplotlib inline magic.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
assert plt

# %% [markdown]
# Change the default chart size to 8 inches width and 8 inches height

# %%
# YOUR CODE HERE
# YOUR CODE HERE
plt.rcParams["figure.figsize"][0] = 8
plt.rcParams["figure.figsize"][1] = 8

# %%
assert plt.rcParams["figure.figsize"][0] == 8
assert plt.rcParams["figure.figsize"][1] == 8

# %% [markdown]
# <hr>

# %% [markdown]
# ### Note about the grading
#
# Grading plots is difficult, we are using `plotchecker` to grade the plots with nbgrader.
# For `plotchecker` to work with nbgrader, we need to add on each cell, the line
#
# `axis = plt.gca();`
#
# <div class="alert alert-danger">
# <b>NOTE:</b>If you get the ImportError, plotchecker not defined, make sure you activate the right environment for this unit!
# </div>
#
# **After the code required to do the plot**.
#
# For example, if we want to plot a scatter plot showing the relationship between revenue and runtime we would do as follows:

# %%
# code required to plot
movies[["budget", "revenue"]].plot.scatter(x="budget",y="revenue" )

# last line in the cell required to "capture" the cell and being able to grade it with nbgrader
axis = plt.gca();

# %% [markdown]
# <hr>

# %% [markdown]
# ### How does the vote count correlate with the revenue?

# %%
# YOUR CODE HERE
movies[['vote_count','revenue']].plot.scatter(x = 'vote_count',y='revenue')
axis = plt.gca();

# %%
from plotchecker import PlotChecker
def get_data(p, ax=0):
    all_x_data = []
    lines = p.axis.get_lines()
    collections = axis.collections
    if len(lines) > 0:
        all_x_data.append(np.concatenate([x.get_xydata()[:, ax] for x in lines]))
    if len(collections) > 0:
        all_x_data.append(np.concatenate([x.get_offsets()[:, ax] for x in collections]))
    return np.concatenate(all_x_data, axis=0)

pc = PlotChecker(axis)
data = get_data(pc)
assert len(data) == 707
assert set([pc.xlabel] + [pc.ylabel]) == set(["revenue", "vote_count"])
np.testing.assert_equal(get_data(pc,1), movies[movies.revenue.notnull()].revenue)
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### How does the average revenue of movies evolves over time? Set the plot title to "Average Movie Revenue by year"

# %% [markdown]
# To calculate the average revenue by year we need to perform an [aggregation](https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html), pandas support this by doing a technique called [Split-Apply-Combine](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html). This will be explained in the Data Wrangling Specialization.

# %% [markdown]
# For now we will do the grouping for you:

# %%
avg_revenue_by_year = movies.groupby("release_year")["revenue"].mean().reset_index()
avg_revenue_by_year.columns = ["release_year", "avg_revenue"]
avg_revenue_by_year.head()
# Out:
#    release_year   avg_revenue
# 0        1951.0  3.616667e+06
# 1        1952.0  8.000000e+06
# 2        1953.0  1.850000e+07
# 3        1955.0  5.000000e+00
# 4        1956.0  8.880000e+06

# %% [markdown]
# <div class="alert alert-danger">
# <b>NOTE:</b>Make sure you use the dataframe named avg_revenue_by_year for the next exercise
# </div>

# %%
ax = movies[['release_year','revenue']].groupby('release_year').mean().plot(title='Average Movie Revenue by year')
ax.set_xlabel('release_year')
ax.set_ylabel('revenue')
axis = plt.gca();

# %%
pc = PlotChecker(axis)
np.testing.assert_equal(get_data(pc), sorted(movies[movies.runtime.notnull()].release_year.unique()))
np.testing.assert_equal(get_data(pc, ax=1), movies.groupby("release_year")["revenue"].mean())

assert set([pc.xlabel] + [pc.ylabel]) == set(["release_year", "revenue"])
pc.assert_title_equal("Average Movie Revenue by year")
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### How does the median revenue vary by movie genre? Label the x-axis as "Median Revenue"

# %% [markdown]
# Again, we will do the grouping for you:

# %%
median_revenue_by_genre = movies.groupby("genre")["revenue"].median().reset_index()
median_revenue_by_genre.columns = ["genre", "median_revenue"]
median_revenue_by_genre

# %% [markdown]
# <div class="alert alert-danger">
# <b>NOTE:</b>Make sure you use the dataframe named median_revenue_by_genre for the next exercise
# </div>

# %%
# YOUR CODE HERE
ax=movies.groupby("genre")["revenue"].median().plot.barh()
ax.set_xlabel('Median Revenue')
ax.set_ylabel('genre')
axis = plt.gca();

# %%
pc = PlotChecker(axis)
pc._patches = np.array(pc.axis.patches)
pc._patches = pc._patches[np.argsort([p.get_x() for p in pc._patches])]
pc.widths = np.array([p.get_width() for p in pc._patches])
pc.heights = np.array([p.get_height() for p in pc._patches])
assert len(pc._patches) == len(movies.groupby("genre").groups)
np.testing.assert_equal(pc.widths, movies.groupby("genre")["revenue"].median().values)
pc.assert_xlabel_equal("Median Revenue")
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### How is the variable vote_average distributed? (set the x axis limit to [0, 9] and the number of bins to 10. Change the bar color to `red`

# %%
# YOUR CODE HERE
ax=movies['vote_average'].hist(bins=10,color='r')
ax.set_xlim(left=0,right=9)
#print(ax.xlim[1])
axis = plt.gca();

# %%
pc = PlotChecker(axis)
pc._patches = np.array(pc.axis.patches)
pc._patches = pc._patches[np.argsort([p.get_x() for p in pc._patches])]
pc.widths = np.array([p.get_width() for p in pc._patches])
pc.heights = np.array([p.get_height() for p in pc._patches])

np.testing.assert_allclose(pc.heights, [  5.,   1.,   1.,   8.,  14.,  58., 202., 231., 172.,  20.])
np.testing.assert_allclose(pc.widths, [0.86 for i in range(len(pc.widths))])
assert pc.xlim[1] == 9
assert pc._patches[0].get_facecolor() == (1., 0., 0., 1.)
print("Success!")
# Out:
# Success!

# %% [markdown]
# ### Change the default plot style to `ggplot`. Make a plot that displays the vote count broken by movie language and that allows us to check if there are outliers.

# %%
movies
# Out:
#          budget            genre original_language  \
# 0     3500000.0           Comedy                en
# 1    12000000.0           Comedy                en
# 2    31000000.0           Comedy                en
# 3    52000000.0            Drama                en
# 4     2000000.0           Comedy                en
# 5    90000000.0  Science Fiction                en
# 6      150000.0           Comedy                en
# 7    14000000.0         Thriller                en
# 8    10000000.0           Comedy                en
# 9       27000.0           Comedy                en
# 10   16000000.0           Comedy                en
# 11     700000.0      Documentary                en
# 12   17000000.0            Drama                en
# 13   35000000.0        Animation                en
# 14   11500000.0            Drama                en
# 15   12000000.0        Adventure                en
# 16   26000000.0            Drama                en
# 17   11000000.0           Comedy                en
# 18   12000000.0            Drama                en
# 19   12000000.0           Comedy                en
# 20   57000000.0          Fantasy                en
# 21    9000000.0  Science Fiction                en
# 22   27000000.0           Comedy                en
# 23   26000000.0           Comedy                en
# 24          NaN              NaN               NaN
# 25          NaN              NaN               NaN
# 26          1.0            Drama                en
# 27     114000.0           Horror                en
# 28   14000000.0           Comedy                en
# 29   48000000.0        Adventure                en
# ..          ...              ...               ...
# 726   2500000.0           Comedy                en
# 727  45000000.0           Comedy                en
# 728  25000000.0            Drama                en
# 729  24000000.0            Drama                en
# 730   6000000.0            Drama                en
# 731   7000000.0            Drama                en
# 732  38000000.0           Comedy                en
# 733  10400000.0            Drama                hi
# 734   1500000.0            Drama                en
# 735  25000000.0           Horror                en
# 736  17820000.0           Comedy                fr
# 737   3500000.0           Action                ru
# 738   7000000.0            Drama                en
# 739    916000.0            Drama                en
# 740   6000000.0            Drama                ru
# 741     64200.0           Comedy                en
# 742    707503.0           Comedy                ru
# 743   2000000.0              NaN                en
# 744   6500000.0           Comedy                ru
# 745   6000000.0           Action                ru
# 746   2500000.0              NaN                ru
# 747   2000000.0           Comedy                ru
# 748         NaN              NaN               NaN
# 749         NaN              NaN               NaN
# 750   5000000.0           Horror                fr
# 751  10000000.0            Drama                en
# 752  10000000.0  Science Fiction                en
# 753   1800000.0  Science Fiction                en
# 754   1500000.0           Horror                en
# 755   5000000.0            Drama                en
#
#                          production_company        production_country  \
# 0                           New Line Cinema  United States of America
# 1                        Universal Pictures  United States of America
# 2                            United Artists  United States of America
# 3                     Imagine Entertainment  United States of America
# 4                             Miramax Films  United States of America
# 5                        Hollywood Pictures  United States of America
# 6                         Party Productions  United States of America
# 7                        Hollywood Pictures  United States of America
# 8               Jack Giarraputo Productions  United States of America
# 9                             Miramax Films  United States of America
# 10                          New Line Cinema  United States of America
# 11                       Fine Line Features  United States of America
# 12                       Paramount Pictures  United States of America
# 13                   Rich Animation Studios  United States of America
# 14                       Universal Pictures  United States of America
# 15            Columbia Pictures Corporation  United States of America
# 16                         TriStar Pictures  United States of America
# 17                      Touchstone Pictures  United States of America
# 18                         TriStar Pictures  United States of America
# 19                 Fox Searchlight Pictures  United States of America
# 20                       Universal Pictures  United States of America
# 21                       Paramount Pictures  United States of America
# 22    Motion Picture Corporation of America  United States of America
# 23                  Scott Rudin Productions  United States of America
# 24                                      NaN                       NaN
# 25                                      NaN                       NaN
# 26                             Warner Bros.  United States of America
# 27                             Laurel Group  United States of America
# 28                              Walt Disney  United States of America
# 29                             Warner Bros.  United States of America
# ..                                      ...                       ...
# 726              Worldwide Media Conspiracy  United States of America
# 727                      Paramount Pictures  United States of America
# 728                       Fox 2000 Pictures  United States of America
# 729                      Paramount Pictures  United States of America
# 730                        Younger Than You  United States of America
# 731                      Annapurna Pictures  United States of America
# 732  Twentieth Century Fox Film Corporation  United States of America
# 733                    Walt Disney Pictures                     India
# 734                        Visible Pictures  United States of America
# 735                      Paramount Pictures  United States of America
# 736                            Studio Canal                    France
# 737                                     NaN                    Russia
# 738                Fox Searchlight Pictures  United States of America
# 739                   Imagine Entertainment  United States of America
# 740                                     NaN                       NaN
# 741                               Arzu Film                    Turkey
# 742                   Yellow, Black & White                    Russia
# 743                                     NaN                    Russia
# 744                                     TNT                    Russia
# 745                     Central Partnership                    Russia
# 746                                     NaN                    Russia
# 747                                     NaN                    Russia
# 748                                     NaN                       NaN
# 749                                     NaN                       NaN
# 750                           La Fabrique 2                    France
# 751                         New Line Cinema  United States of America
# 752                          Rogue Pictures  United States of America
# 753                                     NaN                    Canada
# 754             A. Ninety-Three Productions  United States of America
# 755                                     NaN  United States of America
#
#          revenue  runtime                          title  vote_average  \
# 0     28215918.0     91.0                         Friday           7.0
# 1     41205099.0     92.0                  Happy Gilmore           6.5
# 2    185260553.0    117.0                   The Birdcage           6.7
# 3    355237933.0    140.0                      Apollo 13           7.3
# 4      1275000.0     83.0               Blue in the Face           6.8
# 5    113493481.0     96.0                    Judge Dredd           5.4
# 6       472370.0     94.0                     Party Girl           5.8
# 7      5780000.0     99.0             The Tie That Binds           4.6
# 8     26488734.0     89.0                  Billy Madison           6.2
# 9      3151130.0     92.0                         Clerks           7.4
# 10   247275374.0    107.0                Dumb and Dumber           6.5
# 11     7830611.0    171.0                    Hoop Dreams           7.7
# 12     7603766.0    106.0                  Losing Isaiah           6.4
# 13     9771658.0     89.0              The Swan Princess           6.5
# 14    20079850.0     99.0                  Reality Bites           6.5
# 15    15826984.0    107.0            The Next Karate Kid           4.8
# 16   206678440.0    125.0                   Philadelphia           7.6
# 17    11439193.0     97.0                        The Ref           6.7
# 18    22750363.0    114.0                           Rudy           7.2
# 19     4939939.0    108.0                         Girl 6           5.7
# 20   115267375.0    103.0                    DragonHeart           6.4
# 21     2500000.0     98.0                     Barbarella           5.7
# 22    25023434.0    113.0                        Kingpin           6.7
# 23   116400000.0    102.0           The First Wives Club           6.5
# 24           NaN      NaN                            NaN           NaN
# 25           NaN      NaN                            NaN           NaN
# 26           5.0    115.0                   East of Eden           7.5
# 27    30000000.0     96.0       Night of the Living Dead           7.5
# 28   154864401.0     98.0                  Cool Runnings           6.8
# 29   390493908.0    143.0  Robin Hood: Prince of Thieves           6.6
# ..           ...      ...                            ...           ...
# 726     230069.0     84.0  Jimmy Vestvood: Amerikan Hero           5.4
# 727  114501299.0    105.0         Office Christmas Party           5.4
# 728  230698791.0    127.0                 Hidden Figures           7.8
# 729   64414761.0    139.0                         Fences           6.7
# 730    6174491.0    116.0                 Bleed for This           6.7
# 731    5816211.0    119.0             20th Century Women           7.3
# 732  118034273.0    111.0                       Why Him?           6.3
# 733  310000000.0    161.0                         Dangal           8.0
# 734    2000000.0    112.0                I'm Not Ashamed           7.0
# 735   83080890.0    102.0                          Rings           4.8
# 736   14054361.0     94.0                     RRRrrrr!!!           6.2
# 737    8262833.0    126.0                   Shadowboxing           5.0
# 738   37461045.0    101.0                         Gifted           7.7
# 739    2403885.0     99.0                      Lowriders           7.0
# 740      31000.0      NaN                        Королёв           1.0
# 741     698200.0     94.0                    Tosun Pasha           8.6
# 742    4781454.0     90.0               Have Fun, Vasya!           7.2
# 743   22212223.0     85.0     Nasha Russia: Yaytsa sudby           4.6
# 744    9816332.0    102.0            The Best Movie 3-DE           3.0
# 745   11171900.0    135.0         Boj S Tenyu 2: Revansh           5.6
# 746    1477030.0      0.0                 Glukhar v kino           5.9
# 747    8000000.0     81.0                       Pregnant           3.1
# 748          NaN      NaN                            NaN           NaN
# 749          NaN      NaN                            NaN           NaN
# 750          NaN     92.0                          Livid           5.6
# 751          NaN    118.0                 Price of Glory           3.4
# 752   66821036.0    100.0                        Skyline           4.7
# 753          NaN     84.0            Earth's Final Hours           4.8
# 754          NaN     90.0   Amityville: A New Generation           2.8
# 755          NaN     95.0                     Video Girl           5.0
#
#      vote_count  release_year
# 0         513.0        1995.0
# 1         767.0        1996.0
# 2         303.0        1996.0
# 3        1637.0        1995.0
# 4          28.0        1995.0
# 5         643.0        1995.0
# 6          14.0        1995.0
# 7           9.0        1995.0
# 8         464.0        1995.0
# 9         769.0        1994.0
# 10       1894.0        1994.0
# 11         91.0        1994.0
# 12         28.0        1995.0
# 13        251.0        1994.0
# 14        180.0        1994.0
# 15        202.0        1994.0
# 16       1019.0        1993.0
# 17         99.0        1994.0
# 18        187.0        1993.0
# 19         17.0        1996.0
# 20        553.0        1996.0
# 21        149.0        1968.0
# 22        248.0        1996.0
# 23        172.0        1996.0
# 24          NaN           NaN
# 25          NaN           NaN
# 26        163.0        1955.0
# 27        591.0        1968.0
# 28        510.0        1993.0
# 29        937.0        1991.0
# ..          ...           ...
# 726        14.0        2016.0
# 727       541.0        2016.0
# 728      2178.0        2016.0
# 729       750.0        2016.0
# 730       192.0        2016.0
# 731       213.0        2016.0
# 732      1203.0        2016.0
# 733       140.0        2016.0
# 734        27.0        2016.0
# 735      1075.0        2017.0
# 736       228.0        2004.0
# 737        13.0        2005.0
# 738       549.0        2017.0
# 739        20.0        2017.0
# 740         1.0        2007.0
# 741        10.0        1976.0
# 742        13.0        2017.0
# 743        15.0        2010.0
# 744         8.0        2011.0
# 745         5.0        2007.0
# 746         4.0        2010.0
# 747         7.0        2011.0
# 748         NaN           NaN
# 749         NaN           NaN
# 750        56.0        2011.0
# 751         4.0        2000.0
# 752       516.0        2010.0
# 753        18.0        2011.0
# 754        17.0        1993.0
# 755         3.0        2011.0
#
# [756 rows x 11 columns]

# %%
# YOUR CODE HERE
plt.style.use('ggplot')
ax = movies.boxplot(by='original_language',column='vote_count')
axis = plt.gca();

# %%
pc = PlotChecker(axis)
pc._lines = pc.axis.get_lines()
pc.colors = np.array([pc._color2rgb(x.get_color()) for x in pc._lines])
np.testing.assert_allclose(pc.colors[0],[0.88627451, 0.29019608, 0.2])
np.testing.assert_allclose(pc.yticks,np.array([-1,0,1,2,3,4,5,6])*1e3)
assert pc.xticklabels == ['en', 'fr', 'hi', 'it', 'ru']
print("Success!")
# Out:
# Success!

# %% [markdown]
# # Ungraded Exercise
# Load the file misterious_data.csv and use data visualization to answer the following questions:
#
# * How is the distribution of x in general?
# * Are there any outlier in any of the fields?
# * Which 2 charts better represent the underlying data?. Change their style to `bmh` and add titles to each chart explaining them
